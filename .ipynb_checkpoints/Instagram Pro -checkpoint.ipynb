# %%
# Author: AmirHossein Alyian
# Date: 2022/3/2

# %%
from instagrapi import Client

# %%
cl = Client()

# %%
USER = "amirh4lyian"
PASS = "CIV8kvub3z"

# %%
cl.login(USER, PASS)
# Out:
# True

# %%
'''
if "username" in kwargs:
    user = kwargs["username"]
    user_id = cl.user_id_from_username(user)
elif "userid" in kwargs:
    user_id = kwargs["userid"]
else:
    return -1
'''
# Out:
# '\nif "username" in kwargs:\n    user = kwargs["username"]\n    user_id = cl.user_id_from_username(user)\nelif "userid" in kwargs:\n    user_id = kwargs["userid"]\nelse:\n    return -1\n'

# %%
class User:
    
    def __init__(self, username):
        self.username = username
        self.userid = cl.user_id_from_username(username)
    
    def get_following(self):
        '''this function will find user following'''
        
        data = cl.user_following(self.userid)
        data = list(data.values())
        
        users = set()
        for i in range(len(data)):
            key = str(data[i])
            a = key.find("' username='") + len("', username='") -1
            b = key.find("' full_name=")
            users.add(key[a:b])
        return users
    
    def get_followers(self):
        '''this function will find user followers'''
        
        data = cl.user_followers(self.userid)
        data = list(data.values())

        users = set()
        for i in range(len(data)):
            key = str(data[i])
            a = key.find("' username='") + len("', username='") -1
            b = key.find("' full_name=")
            users.add(key[a:b])
        return users

# %%
arya = User("aryaramnes20")
arya.get_following()
# Out:
# {'13___narut0',
#  '2002_hamid_',
#  '206trendy',
#  '30na.cna',
#  '3rfan24',
#  '7mr_solution7',
#  '81pariiiisa',
#  '__.skytears.__',
#  '__yalda__01',
#  '_aylar.zh_',
#  '_behnam2540',
#  '_coffeegame',
#  '_daaneshjo_',
#  '_itmaryomi_',
#  '_mahdi.jafarzade',
#  '_pxp_art',
#  '_y30in_',
#  'aalty__',
#  'aapt1720',
#  'abbasali_dooblor',
#  'abi.tti',
#  'abolfazl_valizadeh_2002',
#  'abrishamak',
#  'adinehbook',
#  'adnan_relation',
#  'advertising.toktam',
#  'agentrosehq',
#  'ahmadreza.barati78',
#  'ahoomir',
#  'alca_electronics',
#  'alexis_albouhair',
#  'ali._.frye',
#  'ali_behnik',
#  'alii__ksh',
#  'alinamazi._',
#  'alireza.moheb.elahi',
#  'alireza_rabiee1',
#  'aliz_officiall',
#  'aminreza_fathi',
#  'amir.ali_sd82',
#  'amir.m.lotfi1',
#  'amir139822',
#  'amir_invader',
#  'amirali.teybi',
#  'amirh4lyian',
#  'amirrem_',
#  'amirtarsa_',
#  'anjamsam',
#  'arash.salahii',
#  'arash__intelligence',
#  'arawz_',
#  'arayeshi_germany',
#  'arefe_ap',
#  'arta_fitness_',
#  'artillu.ir',
#  'aslekar13',
#  'atikan6909',
#  'awrian.gh',
#  'azaruniv.research',
#  'azroyal_baku.co',
#  'badtvmedia',
#  'banafshiat',
#  'baqytjan_bejey',
#  'batis_mod',
#  'battlebox.ir',
#  'behbahan.taravat',
#  'behteam',
#  'behzadvaredi',
#  'bhr._.dht',
#  'bitpull_crypto',
#  'blubank_com',
#  'bombcamera',
#  'brand_galeryy',
#  'bugda_media',
#  'cafe_dada20',
#  'cafe_pakhsh',
#  'cafiteh',
#  'chet_met__',
#  'club_songs',
#  'coffe_tarfand',
#  'coffee.shot_beh',
#  'coverbank_ir',
#  'crazymindsmedia',
#  'cs_jam',
#  'cyanpub',
#  'dejavu.beh',
#  'diegodevgt',
#  'digesttt.podcast',
#  'digikharid_com',
#  'digimoviez',
#  'diplomat_center',
#  'donya_ertebat',
#  'doone.herb',
#  'dr.izadkhah',
#  'dr.katoozpour',
#  'dr.yasamin.sadeghdoost',
#  'dr.zahramoosavi',
#  'dr_narges_kavoosianpuor',
#  'dreamydeep',
#  'dreshgholi',
#  'drlazyyy',
#  'efficient_education',
#  'elderproducts',
#  'electronic_team_top',
#  'esoleimany_ir',
#  'fa._.friend',
#  'farahmand_alipour',
#  'farshadesmailian',
#  'farsipuzzle2',
#  'fati__friend',
#  'ferferi.coffeee',
#  'fforniaa',
#  'filmkhobb',
#  'firdaws_lives',
#  'fitnessby_ky',
#  'fk_orca',
#  'food_tester20',
#  'frowwn',
#  'gaarson',
#  'gakerbarber',
#  'gallery_bulbings',
#  'gallery_modena24',
#  'galleryganj.offical',
#  'garbagedata',
#  'ghalamchi.behbahan.pesar',
#  'giragap',
#  'gkshop_iran',
#  'goloboll',
#  'h4shur',
#  'h_moallemian',
#  'hadi_nasirpour.z',
#  'haircutsboys',
#  'hamnamakstore',
#  'haniii_7995',
#  'hatroniran',
#  'hello.ukraine1',
#  'hesamalinezhad',
#  'hesampeyrovi_',
#  'heshmat.ebrahimii',
#  'hezarpaa.ir',
#  'holoufun',
#  'honar.seda',
#  'hoopoe.life',
#  'hoopoemag',
#  'hqroz',
#  'hsam.alizade',
#  'hussein.rajabi',
#  'hyperria',
#  'ice.girl0050',
#  'igo3t',
#  'ili.faackt',
#  'imlc_ir',
#  'infinitely_eternal.ir',
#  'infinity_tuning',
#  'inter.pashmam',
#  'invisdreams',
#  'irandeliver',
#  'iranian_3',
#  'iranicardcom',
#  'irankhodro.ikco',
#  'iranyuzcom',
#  'iranzamin.ir',
#  'ishervin.pv',
#  'italiife',
#  'itcamirreza',
#  'itmossi',
#  'janeeshgh',
#  'jinagallerry',
#  'kafshvarzeshii',
#  'kasra_rahimi79',
#  'katooni.behmard',
#  'katooni_basketball',
#  'keywork_ir',
#  'khakzad',
#  'khalil_feizy',
#  'kharchangtv',
#  'kheradgan_official',
#  'kng.cvee',
#  'kob3sher',
#  'kob3shr',
#  'korosh00775',
#  'labkhandoon',
#  'lash.star.accessory',
#  'lash.star.gallery',
#  'lelya_tali',
#  'lilsherwin',
#  'linuxiha',
#  'lioncomputer.ir',
#  'lokakofood',
#  'lovemood.ir',
#  'm.e.h.d.i_n_82',
#  'm_asadi_i5',
#  'maahband',
#  'magicmaji',
#  'mahta__shams',
#  'mailscraper',
#  'majidjalali1335',
#  'manchinni_',
#  'marall.3405',
#  'markamod_pants',
#  'markamod_shoes',
#  'markamod_socks',
#  'marvel_tradee',
#  'matinasliii',
#  'matitanium',
#  'max__graphy',
#  'maybedoniw',
#  'medical_science_stu',
#  'mehrankhosravani',
#  'memeiick',
#  'memenamak',
#  'mensclubper',
#  'mensright__ir2',
#  'mester_kado',
#  'mimclub2021',
#  'missdorsa28',
#  'mitra_s_1999',
#  'mmdrzwartwork',
#  'mmig_mmig',
#  'moein.turk._.oghlan',
#  'mohamad_abbasi7857',
#  'mohammad_m.p.o.r.1',
#  'mohammadnateghi',
#  'mohsen.rhm1999',
#  'mollanasraddinx',
#  'mostafa_bagherii',
#  'mr.chate',
#  'mr.mimbaz',
#  'msarimakhtar',
#  'muhammedsalah_',
#  'nano_tiklike',
#  'navid.ra.n',
#  'nilgamgroup',
#  'niloufarshojaei66',
#  'no28pavement',
#  'nobodys.left',
#  'nulldevelopr',
#  'ohkimiaa',
#  'omidhedayatii',
#  'opencontent.ir',
#  'oxygenclub30',
#  'pabastmehdi',
#  'paeez81.cafe',
#  'panshtaa',
#  'parche_saray_taj',
#  'parikhamse69',
#  'pasta_orange',
#  'payam__zaki',
#  'persialady.ir',
#  'persian_iranian_its_all_about',
#  'persiansoverheard',
#  'pharsa.men',
#  'photo_cheek',
#  'planktune',
#  'pollariiis',
#  'poolak.beh1',
#  'pooya.pishyar',
#  'psl_pubgm',
#  'rafieienglishclinic',
#  'rage__men',
#  'rangi_rangi_socks',
#  'rap_farsinewz',
#  'regina_accessory',
#  'reltip',
#  'rezasamali.ir',
#  'ricco.sport_',
#  'roolstore',
#  'roozi_roozegari98',
#  'royalbarber.iran',
#  'ruttu_ruttu',
#  's.mm.sadrossadati',
#  'sadegh.hedayatnia',
#  'sadegh_alhosseini',
#  'sadramohaqeq',
#  'saeed_nameresan',
#  'saeidpanjehshahin',
#  'said.malahi72',
#  'saleh.tasbihi',
#  'samimorii',
#  'sarcastic_us',
#  'savages.style',
#  'savash2444',
#  'selfish_text',
#  'seryalmood',
#  'shabnam.keyvanian',
#  'shamsiahassani',
#  'shayansarhadi_',
#  'shervinsk_',
#  'shir_asli',
#  'shirazlug.ir',
#  'shit.ism',
#  'shytanat',
#  'sibmobilegaledar_janebi',
#  'sina__dejavu',
#  'sookhtejet.ir',
#  'soolibaa',
#  'sorin_shoes',
#  'speakingir',
#  'sport_newcollection',
#  'sss__8000__',
#  'stavitastore',
#  'stoke_laptop_store',
#  'tanhaabato',
#  'tec_caf',
#  'tech_timez',
#  'tech_timez1',
#  'tehlug',
#  'tehrancollageshop',
#  'tehrun_runningclub',
#  'textbehbahani',
#  'teyzerman',
#  'tg._.edit',
#  'the.yl',
#  'theafchub',
#  'thedigitalocean',
#  'thehackernews',
#  'thescifinet',
#  'tindernightmares',
#  'toluenou_ir',
#  'tomaszschwiertz',
#  'toxic____femininity',
#  'ubuntu_ir',
#  'uhpesar',
#  'utype_ir',
#  'vahid.rajabloo',
#  'venoir206',
#  'venusclip',
#  'veyyman',
#  'viramon_smartening',
#  'vvahideh.molavi',
#  'wahl_star',
#  'weekendi.shop',
#  'wensonico',
#  'where.to.buy.that',
#  'winchi.co',
#  'witch_.meme',
#  'xiaomitec',
#  'xkcdcomic',
#  'xp_ways',
#  'yoo.ost',
#  'young_gallerry',
#  'zard.galllery',
#  'zavano_official',
#  'zero_bam',
#  'zheste_akkasi'}

# %%
listx = get_followers(username="aryaramnes20")
listx
# Out:
# {'30na.cna',
#  '3rfan24',
#  '__.skytears.__',
#  '_aylar.zh_',
#  '_better_world____',
#  'abi.tti',
#  'abolfazl_valizadeh_2002',
#  'ahmadreza.barati78',
#  'ali._.frye',
#  'amiir_salmani',
#  'aminreza_fathi',
#  'amir.m.lotfi1',
#  'amir139822',
#  'amirali.teybi',
#  'amirh4lyian',
#  'amirhd__',
#  'amirtarsa_',
#  'anjamsam',
#  'arash.salahii',
#  'atikan6909',
#  'awrian.gh',
#  'bf_fanorg',
#  'bugda_media',
#  'codingwithayush',
#  'coffee.shot_beh',
#  'delphiacademy.ir',
#  'dreamydeep',
#  'educ_page',
#  'ferferi.coffeee',
#  'flying.scissors',
#  'foroshgah.timber.land.53',
#  'fun._kadee',
#  'gallery_modena24',
#  'ghalamchi.behbahan.pesar',
#  'hadi_nasirpour.z',
#  'hosein.sazgar',
#  'invisdreams',
#  'ishervin.pv',
#  'jomejamshidi810',
#  'kasra_rahimi79',
#  'kng.cvee',
#  'learn_pythonn',
#  'm_asadi_i5',
#  'madark257',
#  'mhd_shoghi',
#  'mitra_s_1999',
#  'moein.turk._.oghlan',
#  'mosakord1238',
#  'parche_saray_taj',
#  'parisa.zm0',
#  'payam__zaki',
#  'persialady.ir',
#  'persian_iranian_its_all_about',
#  'pooya.pishyar',
#  'psychic_reading_angela80',
#  'qwerdsafg5',
#  'reo._091',
#  'rezman_rahinan',
#  'saeed_ibm',
#  'samsalehi777',
#  'savash2444',
#  'shab.nam4533',
#  'shahin_oruogzadeh',
#  'shayansarhadi_',
#  'shervinsk_',
#  'sina__dejavu',
#  'singularitynews',
#  'top_4_signal',
#  'tymwry6759',
#  'zaferanoriginall',
#  'zard.galllery',
#  'zero_bam'}
